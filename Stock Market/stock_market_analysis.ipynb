# %%
import pandas as pd
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import seaborn as sns

# %%
folder_path = '/content/drive/MyDrive/Stock Market/ETFs'

# %%
file_list = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith(".txt")]

# %%
file_list = glob.glob(os.path.join(folder_path, "*.txt"))

# %%
df_list = [pd.read_csv(file) for file in file_list]
combined_df = pd.concat(df_list, ignore_index=True)

# %%
combined_df.head()
# Out:
#          Date    Open    High     Low   Close  Volume  OpenInt
# 0  2005-02-25  33.818  34.771  33.800  34.703   79724        0
# 1  2005-02-28  34.938  34.996  33.943  33.943  140228        0
# 2  2005-03-01  34.070  34.137  33.994  34.062   34404        0
# 3  2005-03-02  33.379  33.665  33.379  33.573   54338        0
# 4  2005-03-03  33.573  33.573  33.085  33.278   23016        0

# %%
combined_df.shape
# Out:
# (2565578, 7)

# %%
combined_df.nunique()
# Out:
# Date         4701
# Open       166263
# High       182024
# Low        181047
# Close      174177
# Volume     782003
# OpenInt         1
# dtype: int64

# %%
df = combined_df.columns
df
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt'], dtype='object')

# %%
df = combined_df.drop(['Date'], axis=1)

# %%
df.head()
# Out:
#      Open    High     Low   Close  Volume  OpenInt
# 0  33.818  34.771  33.800  34.703   79724        0
# 1  34.938  34.996  33.943  33.943  140228        0
# 2  34.070  34.137  33.994  34.062   34404        0
# 3  33.379  33.665  33.379  33.573   54338        0
# 4  33.573  33.573  33.085  33.278   23016        0

# %%
df.corr()
# Out:
#              Open      High       Low     Close    Volume  OpenInt
# Open     1.000000  0.998848  0.999296  0.997817 -0.001674      NaN
# High     0.998848  1.000000  0.998906  0.999064 -0.001669      NaN
# Low      0.999296  0.998906  1.000000  0.998889 -0.001674      NaN
# Close    0.997817  0.999064  0.998889  1.000000 -0.001671      NaN
# Volume  -0.001674 -0.001669 -0.001674 -0.001671  1.000000      NaN
# OpenInt       NaN       NaN       NaN       NaN       NaN      NaN

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >
